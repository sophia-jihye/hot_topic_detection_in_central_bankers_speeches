# %%
import os, re
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas()
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

# %%
filepath = 'data/Fed_chairs_199701-201909_491.csv'
save_filepath = 'data/preprocessed_1997Q1-2019Q3.csv'

# %%
df = pd.read_csv(filepath)
df.head()
# Out:
#                                              content        date       key  \
# 0  Mr Greenspan discusses technology and the US e...  2000-01-17  r000117a
# 1  Mr Greenspan gives a testimony on over-the-cou...  2000-02-16  r000216a
# 2  Mr Greenspan presents the Federal Reserve’s se...  2000-02-18  r000218b
# 3  Mr Greenspan focuses on the revolution in info...  2000-02-10  r000310a
# 4  Mr Greenspan remarks on some of the economic c...  2000-02-24  r000324a
#
#                                    pdf_url  \
# 0  https://www.bis.org/review/r000117a.pdf
# 1  https://www.bis.org/review/r000216a.pdf
# 2  https://www.bis.org/review/r000218b.pdf
# 3  https://www.bis.org/review/r000310a.pdf
# 4  https://www.bis.org/review/r000324a.pdf
#
#                                           short_info    speaker  \
# 0  Remarks by Mr Alan Greenspan  Chairman of the ...  Greenspan
# 1  Testimony of Mr Alan Greenspan  Chairman of th...  Greenspan
# 2  Testimony of Mr Alan Greenspan  Chairman of th...  Greenspan
# 3  Speech by Mr Alan Greenspan  Chairman of the B...  Greenspan
# 4  Remarks by Mr Alan Greenspan  Chairman of the ...  Greenspan
#
#                                                title
# 0  Mr Greenspan discusses technology and the US e...
# 1  Mr Greenspan gives a testimony on over-the-cou...
# 2  Mr Greenspan presents the Federal Reserve's se...
# 3  Mr Greenspan focuses on the revolution in info...
# 4  Mr Greenspan remarks on some of the economic c...

# %%
number_pattern = re.compile('\d+')
def get_sentences(content):
    content = number_pattern.sub(' ', content) # remove_number

    sentences = sent_tokenize(content)
    for i in range(len(sentences)):
        sentences[i] = sentences[i].strip()
    return sentences

df['sentences'] = df.apply(lambda x: get_sentences(x['content']),axis=1)
df.head()
# Out:
#                                              content        date       key  \
# 0  Mr Greenspan discusses technology and the US e...  2000-01-17  r000117a
# 1  Mr Greenspan gives a testimony on over-the-cou...  2000-02-16  r000216a
# 2  Mr Greenspan presents the Federal Reserve’s se...  2000-02-18  r000218b
# 3  Mr Greenspan focuses on the revolution in info...  2000-02-10  r000310a
# 4  Mr Greenspan remarks on some of the economic c...  2000-02-24  r000324a
#
#                                    pdf_url  \
# 0  https://www.bis.org/review/r000117a.pdf
# 1  https://www.bis.org/review/r000216a.pdf
# 2  https://www.bis.org/review/r000218b.pdf
# 3  https://www.bis.org/review/r000310a.pdf
# 4  https://www.bis.org/review/r000324a.pdf
#
#                                           short_info    speaker  \
# 0  Remarks by Mr Alan Greenspan  Chairman of the ...  Greenspan
# 1  Testimony of Mr Alan Greenspan  Chairman of th...  Greenspan
# 2  Testimony of Mr Alan Greenspan  Chairman of th...  Greenspan
# 3  Speech by Mr Alan Greenspan  Chairman of the B...  Greenspan
# 4  Remarks by Mr Alan Greenspan  Chairman of the ...  Greenspan
#
#                                                title  \
# 0  Mr Greenspan discusses technology and the US e...
# 1  Mr Greenspan gives a testimony on over-the-cou...
# 2  Mr Greenspan presents the Federal Reserve's se...
# 3  Mr Greenspan focuses on the revolution in info...
# 4  Mr Greenspan remarks on some of the economic c...
#
#                                            sentences
# 0  [Mr Greenspan discusses technology and the US ...
# 1  [Mr Greenspan gives a testimony on over-the-co...
# 2  [Mr Greenspan presents the Federal Reserve’s s...
# 3  [Mr Greenspan focuses on the revolution in inf...
# 4  [Mr Greenspan remarks on some of the economic ...

# %%
stopword_list = ['alan', 'bank', 'banking', 'ben', 'bernanke', 'bi', 'board',\
                 'central', 'federal', 'financial', 'greenspan', 'ha', 'ii', 'janet',\
                 'jerome', 'market', 'mr', 'percent', 'policy', 'powell']
print('Number of stopwords: {}'.format(len(stopword_list)))
# Out:
# Number of stopwords: 20

# %%
alphabet_pattern = re.compile('[^a-zA-Z]')
doublespace_pattern = re.compile('\s+')
def get_pos_tagged_words(content):
    content = content.lower() # lowercase
    words = word_tokenize(content)

    lemmatizer = WordNetLemmatizer()
    for i in range(len(words)):
        words[i] = lemmatizer.lemmatize(words[i]) # lemmatize
        
        # alphabet_only
        words[i] = alphabet_pattern.sub(' ', words[i])
        words[i] = doublespace_pattern.sub(' ', words[i])
        words[i] = words[i].strip()
    words = [word for word in words if word != '']

    pos_tagged_words = pos_tag(words)

    tag_list = ['NN', 'NNS', 'NNP', 'NNPS', 'JJ', 'JJR', 'JJS', 'RB', 'RBR', 'RBS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
    pos_tagged_words = [(x, y) for (x, y) in pos_tagged_words if y in tag_list]
    pos_tagged_words = [(x, y) for (x, y) in pos_tagged_words if x not in stopword_list]
    
    return pos_tagged_words

df['unigrams_by_sentence'] = df.progress_apply(lambda x: [get_pos_tagged_words(sentence) for sentence in x['sentences']],axis=1)
df.head()
# Out:
# 100%|██████████| 491/491 [01:09<00:00,  7.05it/s]
#                                              content        date       key  \
# 0  Mr Greenspan discusses technology and the US e...  2000-01-17  r000117a
# 1  Mr Greenspan gives a testimony on over-the-cou...  2000-02-16  r000216a
# 2  Mr Greenspan presents the Federal Reserve’s se...  2000-02-18  r000218b
# 3  Mr Greenspan focuses on the revolution in info...  2000-02-10  r000310a
# 4  Mr Greenspan remarks on some of the economic c...  2000-02-24  r000324a
#
#                                    pdf_url  \
# 0  https://www.bis.org/review/r000117a.pdf
# 1  https://www.bis.org/review/r000216a.pdf
# 2  https://www.bis.org/review/r000218b.pdf
# 3  https://www.bis.org/review/r000310a.pdf
# 4  https://www.bis.org/review/r000324a.pdf
#
#                                           short_info    speaker  \
# 0  Remarks by Mr Alan Greenspan  Chairman of the ...  Greenspan
# 1  Testimony of Mr Alan Greenspan  Chairman of th...  Greenspan
# 2  Testimony of Mr Alan Greenspan  Chairman of th...  Greenspan
# 3  Speech by Mr Alan Greenspan  Chairman of the B...  Greenspan
# 4  Remarks by Mr Alan Greenspan  Chairman of the ...  Greenspan
#
#                                                title  \
# 0  Mr Greenspan discusses technology and the US e...
# 1  Mr Greenspan gives a testimony on over-the-cou...
# 2  Mr Greenspan presents the Federal Reserve's se...
# 3  Mr Greenspan focuses on the revolution in info...
# 4  Mr Greenspan remarks on some of the economic c...
#
#                                            sentences  \
# 0  [Mr Greenspan discusses technology and the US ...
# 1  [Mr Greenspan gives a testimony on over-the-co...
# 2  [Mr Greenspan presents the Federal Reserve’s s...
# 3  [Mr Greenspan focuses on the revolution in inf...
# 4  [Mr Greenspan remarks on some of the economic ...
#
#                                 unigrams_by_sentence
# 0  [[(discus, NN), (technology, NN), (u, JJ), (ec...
# 1  [[(give, VBP), (testimony, NN), (over the coun...
# 2  [[(present, VBD), (reserve, NN), (s, VBD), (se...
# 3  [[(focus, NN), (revolution, NN), (information,...
# 4  [[(remark, NN), (economic, JJ), (challenge, NN...

# %%
print(df[df['pdf_url']=='https://www.bis.org/review/r070216a.pdf']['unigrams_by_sentence'].values)
# Out:
# [list([[('s', 'NN'), ('reserve', 'NN'), ('s', 'VBD'), ('semiannual', 'JJ'), ('monetary', 'JJ'), ('report', 'NN'), ('congress', 'NN'), ('testimony', 'NN'), ('s', 'NN'), ('chairman', 'NN'), ('governor', 'NN'), ('u', 'JJ'), ('reserve', 'NN'), ('system', 'NN'), ('committee', 'NN'), ('housing', 'NN'), ('urban', 'JJ'), ('affair', 'NN'), ('u', 'JJ'), ('senate', 'NN'), ('washington', 'NN'), ('february', 'NN')], [('chairman', 'NN'), ('dodd', 'VBZ'), ('senator', 'NN'), ('shelby', 'NN'), ('other', 'JJ'), ('member', 'NN'), ('committee', 'NN'), ('i', 'NN'), ('am', 'VBP'), ('pleased', 'VBN'), ('present', 'VB'), ('reserve', 'NN'), ('s', 'VBD'), ('monetary', 'JJ'), ('report', 'NN'), ('congress', 'NN')], [('real', 'JJ'), ('activity', 'NN'), ('united', 'JJ'), ('state', 'NN'), ('expanded', 'VBD'), ('solid', 'JJ'), ('pace', 'NN'), ('pattern', 'NN'), ('growth', 'NN'), ('wa', 'NN'), ('uneven', 'JJ')], [('first quarter', 'NN'), ('rebound', 'NN'), ('weakness', 'NN'), ('associated', 'VBN'), ('effect', 'NN'), ('hurricane', 'NN'), ('ravaged', 'VBD'), ('gulf', 'NN'), ('coast', 'VBD'), ('previous', 'JJ'), ('summer', 'NN'), ('output', 'NN'), ('growth', 'NN'), ('moderated', 'VBD'), ('somewhat', 'RB'), ('average', 'NN'), ('remainder', 'NN')], [('real', 'JJ'), ('gross', 'JJ'), ('domestic', 'JJ'), ('product', 'NN'), ('gdp', 'NN'), ('is', 'VBZ'), ('currently', 'RB'), ('estimated', 'VBN'), ('have', 'VB'), ('increased', 'VBN'), ('annual', 'JJ'), ('rate', 'NN'), ('second', 'JJ'), ('half', 'NN'), ('year', 'NN')], [('anticipated', 'VBD'), ('july', 'NN'), ('report', 'VB'), ('u s', 'JJ'), ('economy', 'NN'), ('appears', 'VBZ'), ('be', 'VB'), ('making', 'VBG'), ('transition', 'NN'), ('rapid', 'JJ'), ('rate', 'NN'), ('expansion', 'NN'), ('experienced', 'VBN'), ('preceding', 'VBG'), ('several', 'JJ'), ('year', 'NN'), ('more', 'RBR'), ('sustainable', 'JJ'), ('average', 'JJ'), ('pace', 'NN'), ('growth', 'NN')], [('principal', 'JJ'), ('source', 'NN'), ('ongoing', 'JJ'), ('moderation', 'NN'), ('been', 'VBN'), ('substantial', 'JJ'), ('cooling', 'NN'), ('housing', 'NN'), ('led', 'VBN'), ('marked', 'JJ'), ('slowdown', 'NN'), ('pace', 'NN'), ('residential', 'JJ'), ('construction', 'NN')], [('however', 'RB'), ('weakness', 'NN'), ('housing', 'NN'), ('activity', 'NN'), ('slower', 'JJR'), ('appreciation', 'NN'), ('house', 'NN'), ('price', 'NN'), ('do', 'VBP'), ('not', 'RB'), ('seem', 'VB'), ('have', 'VB'), ('spilled', 'VBN'), ('significant', 'JJ'), ('extent', 'NN'), ('other', 'JJ'), ('sector', 'NN'), ('economy', 'NN')], [('consumer', 'NN'), ('spending', 'NN'), ('continued', 'VBD'), ('expand', 'VB'), ('solid', 'JJ'), ('rate', 'NN'), ('demand', 'NN'), ('labor', 'NN'), ('remained', 'VBD'), ('strong', 'JJ')], [('average', 'NN'), ('job', 'NN'), ('month', 'NN'), ('have', 'VBP'), ('been', 'VBN'), ('added', 'VBN'), ('nonfarm', 'VB'), ('payroll', 'NN'), ('past', 'JJ'), ('month', 'NN'), ('unemployment', 'NN'), ('rate', 'NN')], [('january', 'JJ'), ('remains', 'NNS'), ('low', 'JJ')], [('inflation', 'NN'), ('pressure', 'NN'), ('appear', 'VBP'), ('have', 'VB'), ('abated', 'VBN'), ('somewhat', 'RB'), ('following', 'VBG'), ('run up', 'NN'), ('first', 'JJ'), ('half', 'NN')], [('overall', 'JJ'), ('inflation', 'NN'), ('fallen', 'VBN'), ('large', 'JJ'), ('part', 'NN'), ('result', 'NN'), ('decline', 'NN'), ('price', 'NN'), ('crude', 'NN'), ('oil', 'NN')], [('reading', 'VBG'), ('core', 'NN'), ('inflation', 'NN'), ('is', 'VBZ'), ('inflation', 'NN'), ('excluding', 'VBG'), ('price', 'NN'), ('food', 'NN'), ('energy', 'NN'), ('have', 'VBP'), ('improved', 'VBN'), ('modestly', 'RB'), ('recent', 'JJ'), ('month', 'NN')], [('nevertheless', 'RB'), ('core', 'NN'), ('inflation', 'NN'), ('rate', 'NN'), ('remains', 'VBZ'), ('somewhat', 'RB'), ('elevated', 'JJ')], [('meeting', 'NN'), ('july', 'NN'), ('report', 'VBD'), ('open', 'JJ'), ('committee', 'NN'), ('fomc', 'JJ'), ('maintained', 'VBD'), ('fund', 'NN'), ('rate', 'NN')], [('so', 'RB'), ('far', 'RB'), ('incoming', 'NN'), ('data', 'NNS'), ('have', 'VBP'), ('supported', ...

# %%
list_of_words = ['exception', 'is', 'subprime', 'mortgage', 'variable', 'interest', 'rate', 'delinquency', 'rate', 'have', 'increased', 'appreciably']
print(list(zip(list_of_words, list_of_words[1:])))
# Out:
# [('exception', 'is'), ('is', 'subprime'), ('subprime', 'mortgage'), ('mortgage', 'variable'), ('variable', 'interest'), ('interest', 'rate'), ('rate', 'delinquency'), ('delinquency', 'rate'), ('rate', 'have'), ('have', 'increased'), ('increased', 'appreciably')]

# %%
def get_bigrams(unigrams_by_sentence):
    nested_unigrams = unigrams_by_sentence
    unigrams = [word for word, pos in [item for sub in nested_unigrams for item in sub]]
    return list(zip(unigrams, unigrams[1:]))

df['bigrams'] = df['unigrams_by_sentence'].apply(lambda x: get_bigrams(x))
df.head()
# Out:
#                                              content        date       key  \
# 0  Mr Greenspan discusses technology and the US e...  2000-01-17  r000117a
# 1  Mr Greenspan gives a testimony on over-the-cou...  2000-02-16  r000216a
# 2  Mr Greenspan presents the Federal Reserve’s se...  2000-02-18  r000218b
# 3  Mr Greenspan focuses on the revolution in info...  2000-02-10  r000310a
# 4  Mr Greenspan remarks on some of the economic c...  2000-02-24  r000324a
#
#                                    pdf_url  \
# 0  https://www.bis.org/review/r000117a.pdf
# 1  https://www.bis.org/review/r000216a.pdf
# 2  https://www.bis.org/review/r000218b.pdf
# 3  https://www.bis.org/review/r000310a.pdf
# 4  https://www.bis.org/review/r000324a.pdf
#
#                                           short_info    speaker  \
# 0  Remarks by Mr Alan Greenspan  Chairman of the ...  Greenspan
# 1  Testimony of Mr Alan Greenspan  Chairman of th...  Greenspan
# 2  Testimony of Mr Alan Greenspan  Chairman of th...  Greenspan
# 3  Speech by Mr Alan Greenspan  Chairman of the B...  Greenspan
# 4  Remarks by Mr Alan Greenspan  Chairman of the ...  Greenspan
#
#                                                title  \
# 0  Mr Greenspan discusses technology and the US e...
# 1  Mr Greenspan gives a testimony on over-the-cou...
# 2  Mr Greenspan presents the Federal Reserve's se...
# 3  Mr Greenspan focuses on the revolution in info...
# 4  Mr Greenspan remarks on some of the economic c...
#
#                                            sentences  \
# 0  [Mr Greenspan discusses technology and the US ...
# 1  [Mr Greenspan gives a testimony on over-the-co...
# 2  [Mr Greenspan presents the Federal Reserve’s s...
# 3  [Mr Greenspan focuses on the revolution in inf...
# 4  [Mr Greenspan remarks on some of the economic ...
#
#                                 unigrams_by_sentence  num_of_sentences  \
# 0  [[(discus, NN), (technology, NN), (u, JJ), (ec...               187
# 1  [[(give, VBP), (testimony, NN), (over the coun...                69
# 2  [[(present, VBD), (reserve, NN), (s, VBD), (se...               115
# 3  [[(focus, NN), (revolution, NN), (information,...               108
# 4  [[(remark, NN), (economic, JJ), (challenge, NN...               100
#
#                                              bigrams
# 0  [(discus, technology), (technology, u), (u, ec...
# 1  [(give, testimony), (testimony, over the count...
# 2  [(present, reserve), (reserve, s), (s, semi an...
# 3  [(focus, revolution), (revolution, information...
# 4  [(remark, economic), (economic, challenge), (c...

# %%
df[(df['bigrams'].apply(lambda x: ('u', 's') in x))]
# Out:
#                                                content        date       key  \
# 48   Alan Greenspan: Semi-annual monetary policy re...  2002-07-17  r020717a
# 161  Mr. Greenspan's remarks to the Economic Club o...  1997-12-08  r971208d
# 260  Ben S Bernanke: Remarks on Class Day 2008 Spee...  2008-06-06  r080606a
#
#                                      pdf_url  \
# 48   https://www.bis.org/review/r020717a.pdf
# 161  https://www.bis.org/review/r971208d.pdf
# 260  https://www.bis.org/review/r080606a.pdf
#
#                                             short_info    speaker  \
# 48   Testimony of Mr Alan Greenspan  Chairman of th...  Greenspan
# 161  Remarks by the Chairman of the Board of the U ...  Greenspan
# 260  Speech of Mr Ben S Bernanke  Chairman of the B...   Bernanke
#
#                                                  title  \
# 48   Alan Greenspan: Semi-annual monetary policy re...
# 161  Mr. Greenspan's remarks to the Economic Club o...
# 260          Ben S Bernanke: Remarks on Class Day 2008
#
#                                              sentences  \
# 48   [Alan Greenspan: Semi-annual monetary policy r...
# 161  [Mr. Greenspan's remarks to the Economic Club ...
# 260  [Ben S Bernanke: Remarks on Class Day   Speech...
#
#                                   unigrams_by_sentence  num_of_sentences  \
# 48   [[(semi annual, JJ), (monetary, JJ), (report, ...               164
# 161  [[(s, VBP), (remark, NN), (economic, JJ), (clu...               188
# 260  [[(s, NN), (remark, NN), (class, NN), (day, NN...               175
#
#                                                bigrams
# 48   [(semi annual, monetary), (monetary, report), ...
# 161  [(s, remark), (remark, economic), (economic, c...
# 260  [(s, remark), (remark, class), (class, day), (...

# %%
print(df[(df['bigrams'].apply(lambda x: ('u', 's') in x))].iloc[0]['bigrams'])
# Out:
# [('semi annual', 'monetary'), ('monetary', 'report'), ('report', 'u'), ('u', 'congress'), ('congress', 'testimony'), ('testimony', 'chairman'), ('chairman', 'governor'), ('governor', 'u'), ('u', 'reserve'), ('reserve', 'system'), ('system', 'occasion'), ('occasion', 'reserve'), ('reserve', 's'), ('s', 'semiannual'), ('semiannual', 'monetary'), ('monetary', 'report'), ('report', 'congress'), ('congress', 'committee'), ('committee', 'service'), ('service', 'u'), ('u', 'house'), ('house', 'representative'), ('representative', 'july'), ('july', 'i'), ('i', 'appreciate'), ('appreciate', 'opportunity'), ('opportunity', 'present'), ('present', 'reserve'), ('reserve', 's'), ('s', 'monetary'), ('monetary', 'report'), ('report', 'congress'), ('congress', 'one half'), ('one half', 'month'), ('month', 'i'), ('i', 'last'), ('last', 'testified'), ('testified', 'committee'), ('committee', 'monetary'), ('monetary', 'economy'), ('economy', 'continued'), ('continued', 'expand'), ('expand', 'largely'), ('largely', 'broad'), ('broad', 'contour'), ('contour', 'had'), ('had', 'anticipated'), ('anticipated', 'time'), ('time', 'uncertainty'), ('uncertainty', 'earlier'), ('earlier', 'year'), ('year', 'are'), ('are', 'yet'), ('yet', 'not'), ('not', 'fully'), ('fully', 'resolved'), ('resolved', 'u s'), ('u s', 'economy'), ('economy', 'appears'), ('appears', 'have'), ('have', 'withstood'), ('withstood', 'set'), ('set', 'blow'), ('blow', 'major'), ('major', 'decline'), ('decline', 'equity'), ('equity', 'sharp'), ('sharp', 'retrenchment'), ('retrenchment', 'investment'), ('investment', 'spending'), ('spending', 'tragic'), ('tragic', 'terrorist'), ('terrorist', 'attack'), ('attack', 'last'), ('last', 'september'), ('september', 'previous'), ('previous', 'business'), ('business', 'cycle'), ('cycle', 'almost'), ('almost', 'surely'), ('surely', 'have'), ('have', 'induced'), ('induced', 'severe'), ('severe', 'contraction'), ('contraction', 'mildness'), ('mildness', 'brevity'), ('brevity', 'downturn'), ('downturn', 'i'), ('i', 'indicated'), ('indicated', 'earlier'), ('earlier', 'year'), ('year', 'are'), ('are', 'testament'), ('testament', 'notable'), ('notable', 'improvement'), ('improvement', 'resilience'), ('resilience', 'flexibility'), ('flexibility', 'u s'), ('u s', 'economy'), ('economy', 'economy'), ('economy', 'held'), ('held', 'remarkably'), ('remarkably', 'well'), ('well', 'not'), ('not', 'surprisingly'), ('surprisingly', 'depressing'), ('depressing', 'effect'), ('effect', 'recent'), ('recent', 'event'), ('event', 'linger'), ('linger', 'spending'), ('spending', 'continue'), ('continue', 'adjust'), ('adjust', 'time'), ('time', 'decline'), ('decline', 'have'), ('have', 'occurred'), ('occurred', 'equity'), ('equity', 'price'), ('price', 'recent'), ('recent', 'week'), ('week', 'price'), ('price', 'have'), ('have', 'fallen'), ('fallen', 'further'), ('further', 'net'), ('net', 'part'), ('part', 'influence'), ('influence', 'growing'), ('growing', 'concern'), ('concern', 'corporate'), ('corporate', 'governance'), ('governance', 'business'), ('business', 'transparency'), ('transparency', 'problem'), ('problem', 'evidently'), ('evidently', 'accumulated'), ('accumulated', 'earlier'), ('earlier', 'rapid'), ('rapid', 'runup'), ('runup', 'considerable'), ('considerable', 'uncertainty'), ('uncertainty', 'progress'), ('progress', 'adjustment'), ('adjustment', 'capital'), ('capital', 'spending'), ('spending', 'rebound'), ('rebound', 'profitability'), ('profitability', 'potential'), ('potential', 'additional'), ('additional', 'revelation'), ('revelation', 'corporate'), ('corporate', 'malfeasance'), ('malfeasance', 'possible'), ('possible', 'risk'), ('risk', 'global'), ('global', 'political'), ('political', 'event'), ('event', 'terrorism'), ('terrorism', 'still'), ('still', 'confront'), ('confront', 'u'), ('u', 'nevertheless'), ('nevertheless', 'fundamental'), ('fundamental', 'are'), ('are', 'place'), ('place', 'return'), ('return', 'sustained'), ('sustained', 'healthy'), ...

# %%
def remove_outlier_sentence(df):
    for index, row in df.iterrows():
        i = 0
        while i < len(row['sentences']):
            unigrams_len = len(row['unigrams_by_sentence'][i])
            if (unigrams_len < 3) or (unigrams_len > 180):
                del row['sentences'][i]
                del row['unigrams_by_sentence'][i]
                i -= 1
            i += 1
    return df

df = remove_outlier_sentence(df)

df['num_of_sentences'] = df['sentences'].apply(lambda x: len(x))
print('Number of sentences: {}'.format(df['num_of_sentences'].sum()))
# Out:
# Number of sentences: 55458

# %%
list_of_num_of_tokens_in_a_sentence = []
for doc in df['unigrams_by_sentence'].values:
    for sent in doc:
        list_of_num_of_tokens_in_a_sentence.append(len(sent))
print('Average number of tokens in a sentence: {}'.format(np.average(list_of_num_of_tokens_in_a_sentence)))
# Out:
# Average number of tokens in a sentence: 15.316257347902917

# %%
def quarterly_dict():
    def _period_dict(target_dict, _period, start, end):
        for _month in [str('%02d' % i) for i in range(start, end + 1)]:
            target_dict[_month] = _period
        return target_dict
    target_dict = dict()
    target_dict = _period_dict(target_dict, 'Q1', 1, 3)
    target_dict = _period_dict(target_dict, 'Q2', 4, 6)
    target_dict = _period_dict(target_dict, 'Q3', 7, 9)
    target_dict = _period_dict(target_dict, 'Q4', 10, 12)
    return target_dict

period_dict = quarterly_dict()
df['grouping_period'] = df.apply(lambda x: '_'.join([x['date'][:4], period_dict[x['date'][5:7]]]), axis=1)
df.head()
# Out:
#                                              content        date       key  \
# 0  Mr Greenspan discusses technology and the US e...  2000-01-17  r000117a
# 1  Mr Greenspan gives a testimony on over-the-cou...  2000-02-16  r000216a
# 2  Mr Greenspan presents the Federal Reserve’s se...  2000-02-18  r000218b
# 3  Mr Greenspan focuses on the revolution in info...  2000-02-10  r000310a
# 4  Mr Greenspan remarks on some of the economic c...  2000-02-24  r000324a
#
#                                    pdf_url  \
# 0  https://www.bis.org/review/r000117a.pdf
# 1  https://www.bis.org/review/r000216a.pdf
# 2  https://www.bis.org/review/r000218b.pdf
# 3  https://www.bis.org/review/r000310a.pdf
# 4  https://www.bis.org/review/r000324a.pdf
#
#                                           short_info    speaker  \
# 0  Remarks by Mr Alan Greenspan  Chairman of the ...  Greenspan
# 1  Testimony of Mr Alan Greenspan  Chairman of th...  Greenspan
# 2  Testimony of Mr Alan Greenspan  Chairman of th...  Greenspan
# 3  Speech by Mr Alan Greenspan  Chairman of the B...  Greenspan
# 4  Remarks by Mr Alan Greenspan  Chairman of the ...  Greenspan
#
#                                                title  \
# 0  Mr Greenspan discusses technology and the US e...
# 1  Mr Greenspan gives a testimony on over-the-cou...
# 2  Mr Greenspan presents the Federal Reserve's se...
# 3  Mr Greenspan focuses on the revolution in info...
# 4  Mr Greenspan remarks on some of the economic c...
#
#                                            sentences  \
# 0  [Mr Greenspan discusses technology and the US ...
# 1  [Mr Greenspan gives a testimony on over-the-co...
# 2  [Mr Greenspan presents the Federal Reserve’s s...
# 3  [Mr Greenspan focuses on the revolution in inf...
# 4  [Mr Greenspan remarks on some of the economic ...
#
#                                 unigrams_by_sentence  num_of_sentences  \
# 0  [[(discus, NN), (technology, NN), (u, JJ), (ec...               187
# 1  [[(give, VBP), (testimony, NN), (over the coun...                69
# 2  [[(present, VBD), (reserve, NN), (s, VBD), (se...               115
# 3  [[(focus, NN), (revolution, NN), (information,...               108
# 4  [[(remark, NN), (economic, JJ), (challenge, NN...               100
#
#   grouping_period
# 0         2000_Q1
# 1         2000_Q1
# 2         2000_Q1
# 3         2000_Q1
# 4         2000_Q1

# %%
records = []
for period in sorted(df.grouping_period.unique()):
    sentences_for_one_period = []
    for list_of_sentences in df[(df['grouping_period']==period)]['unigrams_by_sentence'].values:
        flattened_sentences = [item for sub in list_of_sentences for item in sub]
        sentences_for_one_period.extend(flattened_sentences)
    tokens = ' '.join([x for x, y in sentences_for_one_period])
    records.append((tokens, period))
    
preprocessed_df = pd.DataFrame(records, columns=['tokens', 'period'])
print('Number of periods: {}'.format(len(preprocessed_df)))
print('Last quarter:', sorted(preprocessed_df['period'].unique())[-1])
preprocessed_df.head()
# Out:
# Number of periods: 91
# Last quarter: 2019_Q3
#                                               tokens   period
# 0  address key role remark chairman governor u re...  1997_Q1
# 1  highlight key aspect current economic situatio...  1997_Q2
# 2  present view reserve semi annual humphrey hawk...  1997_Q3
# 3  considers effect technological change remark c...  1997_Q4
# 4  s remark american economic association america...  1998_Q1

# %%
preprocessed_df['num_of_tokens'] = preprocessed_df['tokens'].apply(lambda x: len(x.split(' ')))
print('Total number of tokens: {}'.format(preprocessed_df['num_of_tokens'].sum()))
preprocessed_df.head()
# Out:
# Total number of tokens: 868838
#                                               tokens   period  num_of_tokens
# 0  address key role remark chairman governor u re...  1997_Q1          16246
# 1  highlight key aspect current economic situatio...  1997_Q2          13432
# 2  present view reserve semi annual humphrey hawk...  1997_Q3           6409
# 3  considers effect technological change remark c...  1997_Q4          15038
# 4  s remark american economic association america...  1998_Q1          10804

# %%
preprocessed_df.to_csv(save_filepath, index=False)
print('Created {}'.format(save_filepath))
# Out:
# Created data/preprocessed_1997Q1-2019Q3.csv
